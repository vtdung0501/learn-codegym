# %%
import turtle as tl
import math
screen = tl.Screen()
screen.bgcolor("light blue")
pen = tl.Turtle()
pen.pensize(3)
edge = 200
degree = 90
def draw_shapes(col,w,h,degree_1,degree_2):
    pen.color(col)
    for i in range(0,2):
        pen.forward(w)
        pen.left(degree_1)
        pen.forward(h)
        pen.left(degree_2)
# vẽ mặt tiền
pen.fillcolor("green")
pen.begin_fill()
draw_shapes("green",edge,edge,degree,degree)
pen.end_fill()
# vẽ cửa chính
pen.penup()
pen.goto(50,0)
pen.pendown()
pen.fillcolor("gray")
pen.begin_fill()
draw_shapes("gray",edge/2,edge/2,90,90)
pen.end_fill()
# Vẽ sườn ngôi nhà
pen.penup()
pen.goto(200,0)
pen.pendown()
pen.fillcolor("blue")
pen.begin_fill()
pen.left(30)
draw_shapes("blue",edge-50,edge,degree-30,degree+30)
pen.end_fill()
# Vẽ cửa sổ
pen.penup()
pen.goto(250,100)
pen.pendown()
pen.fillcolor("brown")
pen.begin_fill()
draw_shapes("brown",edge-150,edge-130,degree-30,degree+30)
pen.end_fill()
# Vẽ mái nhà
pen.penup()
pen.goto(0,200)
pen.pendown()
pen.fillcolor("yellow")
pen.begin_fill()
pen.color("yellow")
pen.right(30)
pen.forward(200)
pen.left(135)
pen.forward(200/math.sqrt(2))
pen.left(90)
pen.forward(200/math.sqrt(2))
pen.end_fill()
pen.penup()
pen.goto(200,200)
pen.pendown()
pen.fillcolor("violet")
pen.begin_fill()
pen.left(165)
draw_shapes("violet",edge-50,edge/math.sqrt(2),105,75)
pen.end_fill()
# Vẽ cây
# vẽ thân cây
pen.penup()
pen.goto(-150,-100)
pen.pendown()
pen.fillcolor("brown")
pen.begin_fill()
pen.right(120)
draw_shapes("brown",edge/2,edge/4,degree,degree)
pen.end_fill()
# Vẽ lá
pen.penup()
pen.goto(-225,-100)
pen.pendown()
pen.left(90)
pen.fillcolor("green")
pen.begin_fill()
pen.color("green")
pen.forward(200)
pen.left(135)
pen.forward(200/math.sqrt(2))
pen.left(90)
pen.forward(200/math.sqrt(2))
for i in range(1,3):
    pen.penup()
    pen.goto(-225,-100 +40*i)
    pen.pendown()
    pen.left(135)
    pen.forward(200)
    pen.left(135)
    pen.forward(200/math.sqrt(2))
    pen.left(90)
    pen.forward(200/math.sqrt(2))
pen.end_fill()
# Vẽ mặt trời
pen.fillcolor("yellow")
pen.begin_fill()
pen.color("yellow")
pen.penup()
pen.goto(-300,300)
pen.pendown()
pen.circle(100)
pen.end_fill()
tl.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# c:\Users\vtdun\Desktop\Learn_CodeGym\DrawHouse.ipynb Cell 1 in <cell line: 27>()
#      <a href='vscode-notebook-cell:/c%3A/Users/vtdun/Desktop/Learn_CodeGym/DrawHouse.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> pen.fillcolor("gray")
#      <a href='vscode-notebook-cell:/c%3A/Users/vtdun/Desktop/Learn_CodeGym/DrawHouse.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> pen.begin_fill()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vtdun/Desktop/Learn_CodeGym/DrawHouse.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> draw_shapes("gray",edge/2,edge/2,90,90)
#      <a href='vscode-notebook-cell:/c%3A/Users/vtdun/Desktop/Learn_CodeGym/DrawHouse.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> pen.end_fill()
#      <a href='vscode-notebook-cell:/c%3A/Users/vtdun/Desktop/Learn_CodeGym/DrawHouse.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> # Vẽ sườn ngôi nhà
#
# ...
